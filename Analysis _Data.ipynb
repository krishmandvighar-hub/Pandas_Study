# %%
import pandas as pd
df =pd.read_csv("ipl_dummy_dataset.csv")
#Task 1 Data Understanding
newdf=df.head(5)
print(df)
# Out:
#       id  season       city                        team1  \
# 0      1    2018    Chennai               Mumbai Indians
# 1      2    2018     Jaipur               Delhi Capitals
# 2      3    2018  Bangalore  Royal Challengers Bangalore
# 3      4    2018      Delhi          Chennai Super Kings
# 4      5    2018    Kolkata  Royal Challengers Bangalore
# ..   ...     ...        ...                          ...
# 145  146    2022      Delhi               Mumbai Indians
# 146  147    2022  Bangalore          Chennai Super Kings
# 147  148    2022      Delhi          Chennai Super Kings
# 148  149    2022     Jaipur               Delhi Capitals
# 149  150    2022  Bangalore               Delhi Capitals
#
#                            team2                  toss_winner toss_decision  \
# 0            Chennai Super Kings               Mumbai Indians           bat
# 1               Rajasthan Royals             Rajasthan Royals         field
# 2               Rajasthan Royals  Royal Challengers Bangalore           bat
# 3    Royal Challengers Bangalore          Chennai Super Kings           bat
# 4          Kolkata Knight Riders        Kolkata Knight Riders           bat
# ..                           ...                          ...           ...
# 145               Delhi Capitals               Mumbai Indians         field
# 146             Rajasthan Royals             Rajasthan Royals           bat
# 147             Rajasthan Royals          Chennai Super Kings           bat
# 148               Mumbai Indians               Delhi Capitals         field
# 149               Mumbai Indians               Delhi Capitals           bat
#
#                           winner player_of_match              venue  runs  \
# 0                 Mumbai Indians        Player C  Bangalore Stadium   207
# 1               Rajasthan Royals        Player B    Kolkata Stadium   140
# 2    Royal Challengers Bangalore        Player B    Kolkata Stadium   179
# 3            Chennai Super Kings        Player B    Kolkata Stadium   208
# 4          Kolkata Knight Riders        Player D      Delhi Stadium   127
# ..                           ...             ...                ...   ...
# 145               Delhi Capitals        Player D  Bangalore Stadium   218
# 146          Chennai Super Kings        Player B    Chennai Stadium   217
# 147          Chennai Super Kings        Player C    Kolkata Stadium   151
# 148               Delhi Capitals        Player D      Delhi Stadium   140
# 149               Delhi Capitals        Player B    Kolkata Stadium   157
#
#      wickets
# 0          4
# 1          0
# 2          2
# 3          1
# 4          2
# ..       ...
# 145        3
# 146        1
# 147        1
# 148        4
# 149        1
#
# [150 rows x 12 columns]

# %%
print("Information: ",df.info())
print("Shape: ",df.shape)
print("indexing: ",df.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               150 non-null    int64
#  1   season           150 non-null    int64
#  2   city             150 non-null    object
#  3   team1            150 non-null    object
#  4   team2            150 non-null    object
#  5   toss_winner      150 non-null    object
#  6   toss_decision    150 non-null    object
#  7   winner           150 non-null    object
#  8   player_of_match  150 non-null    object
#  9   venue            150 non-null    object
#  10  runs             150 non-null    int64
#  11  wickets          150 non-null    int64
# dtypes: int64(4), object(8)
# memory usage: 14.2+ KB
# Information:  None
# Shape:  (150, 12)
# indexing:  Index(['id', 'season', 'city', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'winner', 'player_of_match', 'venue', 'runs',
#        'wickets'],
#       dtype='object')

# %%
newdf=df.isnull().sum()
print(newdf)
# Out:
# id                 0
# season             0
# city               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# player_of_match    0
# venue              0
# runs               0
# wickets            0
# dtype: int64

# %%
#TASK 2. DATA CLEANING
print(df.fillna("Unknown"))
print(df.drop_duplicates())
# Out:
#       id  season       city                        team1  \
# 0      1    2018    Chennai               Mumbai Indians
# 1      2    2018     Jaipur               Delhi Capitals
# 2      3    2018  Bangalore  Royal Challengers Bangalore
# 3      4    2018      Delhi          Chennai Super Kings
# 4      5    2018    Kolkata  Royal Challengers Bangalore
# ..   ...     ...        ...                          ...
# 145  146    2022      Delhi               Mumbai Indians
# 146  147    2022  Bangalore          Chennai Super Kings
# 147  148    2022      Delhi          Chennai Super Kings
# 148  149    2022     Jaipur               Delhi Capitals
# 149  150    2022  Bangalore               Delhi Capitals
#
#                            team2                  toss_winner toss_decision  \
# 0            Chennai Super Kings               Mumbai Indians           bat
# 1               Rajasthan Royals             Rajasthan Royals         field
# 2               Rajasthan Royals  Royal Challengers Bangalore           bat
# 3    Royal Challengers Bangalore          Chennai Super Kings           bat
# 4          Kolkata Knight Riders        Kolkata Knight Riders           bat
# ..                           ...                          ...           ...
# 145               Delhi Capitals               Mumbai Indians         field
# 146             Rajasthan Royals             Rajasthan Royals           bat
# 147             Rajasthan Royals          Chennai Super Kings           bat
# 148               Mumbai Indians               Delhi Capitals         field
# 149               Mumbai Indians               Delhi Capitals           bat
#
#                           winner player_of_match              venue  runs  \
# 0                 Mumbai Indians        Player C  Bangalore Stadium   207
# 1               Rajasthan Royals        Player B    Kolkata Stadium   140
# 2    Royal Challengers Bangalore        Player B    Kolkata Stadium   179
# 3            Chennai Super Kings        Player B    Kolkata Stadium   208
# 4          Kolkata Knight Riders        Player D      Delhi Stadium   127
# ..                           ...             ...                ...   ...
# 145               Delhi Capitals        Player D  Bangalore Stadium   218
# 146          Chennai Super Kings        Player B    Chennai Stadium   217
# 147          Chennai Super Kings        Player C    Kolkata Stadium   151
# 148               Delhi Capitals        Player D      Delhi Stadium   140
# 149               Delhi Capitals        Player B    Kolkata Stadium   157
#
#      wickets
# 0          4
# 1          0
# 2          2
# 3          1
# 4          2
# ..       ...
# 145        3
# 146        1
# 147        1
# 148        4
# 149        1
#
# [150 rows x 12 columns]
#       id  season       city                        team1  \
# 0      1    2018    Chennai               Mumbai Indians
# 1      2    2018     Jaipur               Delhi Capitals
# 2      3    2018  Bangalore  Royal Challengers Bangalore
# 3      4    2018      Delhi          Chennai Super Kings
# 4      5    2018    Kolkata  Royal Challengers Bangalore
# ..   ...     ...        ...                          ...
# 145  146    2022      Delhi               Mumbai Indians
# 146  147    2022  Bangalore          Chennai Super Kings
# 147  148    2022      Delhi          Chennai Super Kings
# 148  149    2022     Jaipur               Delhi Capitals
# 149  150    2022  Bangalore               Delhi Capitals
#
#                            team2                  toss_winner toss_decision  \
# 0            Chennai Super Kings               Mumbai Indians           bat
# 1               Rajasthan Royals             Rajasthan Royals         field
# 2               Rajasthan Royals  Royal Challengers Bangalore           bat
# 3    Royal Challengers Bangalore          Chennai Super Kings           bat
# 4          Kolkata Knight Riders        Kolkata Knight Riders           bat
# ..                           ...                          ...           ...
# 145               Delhi Capitals               Mumbai Indians         field
# 146             Rajasthan Royals             Rajasthan Royals           bat
# 147             Rajasthan Royals          Chennai Super Kings           bat
# 148               Mumbai Indians               Delhi Capitals         field
# 149               Mumbai Indians               Delhi Capitals           bat
#
#                           winner player_of_match              venue  runs  \
# 0                 Mumbai Indians        Player C  Bangalore Stadium   207
# 1               Rajasthan Royals        Player B    Kolkata Stadium   140
# 2    Royal Challengers Bangalore        Player B    Kolkata Stadium   179
# 3            Chennai Super Kings        Player B    Kolkata Stadium   208
# 4          Kolkata Knight Riders        Player D      Delhi Stadium   127
# ..                           ...             ...                ...   ...
# 145               Delhi Capitals        Player D  Bangalore Stadium   218
# 146          Chennai Super Kings        Player B    Chennai Stadium   217
# 147          Chennai Super Kings        Player C    Kolkata Stadium   151
# 148               Delhi Capitals        Player D      Delhi Stadium   140
# 149               Delhi Capitals        Player B    Kolkata Stadium   157
#
#      wickets
# 0          4
# 1          0
# 2          2
# 3          1
# 4          2
# ..       ...
# 145        3
# 146        1
# 147        1
# 148        4
# 149        1
#
# [150 rows x 12 columns]

# %%
print(df.replace("Bangalore","Bangaluru"))
# Out:
#       id  season       city                        team1  \
# 0      1    2018    Chennai               Mumbai Indians
# 1      2    2018     Jaipur               Delhi Capitals
# 2      3    2018  Bangaluru  Royal Challengers Bangalore
# 3      4    2018      Delhi          Chennai Super Kings
# 4      5    2018    Kolkata  Royal Challengers Bangalore
# ..   ...     ...        ...                          ...
# 145  146    2022      Delhi               Mumbai Indians
# 146  147    2022  Bangaluru          Chennai Super Kings
# 147  148    2022      Delhi          Chennai Super Kings
# 148  149    2022     Jaipur               Delhi Capitals
# 149  150    2022  Bangaluru               Delhi Capitals
#
#                            team2                  toss_winner toss_decision  \
# 0            Chennai Super Kings               Mumbai Indians           bat
# 1               Rajasthan Royals             Rajasthan Royals         field
# 2               Rajasthan Royals  Royal Challengers Bangalore           bat
# 3    Royal Challengers Bangalore          Chennai Super Kings           bat
# 4          Kolkata Knight Riders        Kolkata Knight Riders           bat
# ..                           ...                          ...           ...
# 145               Delhi Capitals               Mumbai Indians         field
# 146             Rajasthan Royals             Rajasthan Royals           bat
# 147             Rajasthan Royals          Chennai Super Kings           bat
# 148               Mumbai Indians               Delhi Capitals         field
# 149               Mumbai Indians               Delhi Capitals           bat
#
#                           winner player_of_match              venue  runs  \
# 0                 Mumbai Indians        Player C  Bangalore Stadium   207
# 1               Rajasthan Royals        Player B    Kolkata Stadium   140
# 2    Royal Challengers Bangalore        Player B    Kolkata Stadium   179
# 3            Chennai Super Kings        Player B    Kolkata Stadium   208
# 4          Kolkata Knight Riders        Player D      Delhi Stadium   127
# ..                           ...             ...                ...   ...
# 145               Delhi Capitals        Player D  Bangalore Stadium   218
# 146          Chennai Super Kings        Player B    Chennai Stadium   217
# 147          Chennai Super Kings        Player C    Kolkata Stadium   151
# 148               Delhi Capitals        Player D      Delhi Stadium   140
# 149               Delhi Capitals        Player B    Kolkata Stadium   157
#
#      wickets
# 0          4
# 1          0
# 2          2
# 3          1
# 4          2
# ..       ...
# 145        3
# 146        1
# 147        1
# 148        4
# 149        1
#
# [150 rows x 12 columns]

# %%
print(df.count())
# Out:
# id                 150
# season             150
# city               150
# team1              150
# team2              150
# toss_winner        150
# toss_decision      150
# winner             150
# player_of_match    150
# venue              150
# runs               150
# wickets            150
# dtype: int64

# %%
print("SEASON WISE RUNS" ,df.groupby("season")["runs"].sum(numeric_only=True))
# Out:
# SEASON WISE RUNS season
# 2018    4943
# 2019    4995
# 2020    4971
# 2021    5047
# 2022    5328
# Name: runs, dtype: int64

# %%
#matches Per Season
matches_Per_Season=(
    df.groupby("season")
    .size()
)
print(matches_Per_Season)
# Out:
# season
# 2018    30
# 2019    30
# 2020    30
# 2021    30
# 2022    30
# dtype: int64

# %%
#Most WINNING TEAM
most_wins=df["winner"].value_counts()
print(most_wins)
# Out:
# winner
# Kolkata Knight Riders          32
# Royal Challengers Bangalore    30
# Delhi Capitals                 27
# Chennai Super Kings            26
# Rajasthan Royals               18
# Mumbai Indians                 17
# Name: count, dtype: int64

# %%
#TASK $ TEAM PERFORMANCE
#TOP 3 TEAMS WITH MOST WINS
top_teams = (
    df.groupby("winner")
      .agg(total_wins=("winner", "count"))
      .sort_values(by="total_wins", ascending=False)
      .head(3)
)

print(top_teams)
# Out:
#                              total_wins
# winner
# Kolkata Knight Riders                32
# Royal Challengers Bangalore          30
# Delhi Capitals                       27

# %%
#TOSS WINNER ALSO WON MATCH
df["toss_match_win"]=(df["toss_winner"]==df["winner"])
print(df["toss_match_win"].value_counts())
# Out:
# toss_match_win
# True     93
# False    57
# Name: count, dtype: int64

# %%
percentage=(
    df["toss_match_win"].mean() * 100
)
print(percentage)
# Out:
# 62.0

# %%
#HOME GROUND ADVANTAGE
#TEAM CITY MAPPING
team_city={
    "Mumbai Indians":"Mumbai",
    "Chennai Super Kings":"Chennai",
    "Royal Challengers Bangalore":"Bangalore",
    "Delhi Capitals":"Delhi",
    "Kolkata Knight Riders":"Kolkata",
    "Rajasthan Royals":"Jaipur"
}
df["home_team"]=df["city"].map(
    {v:k for k,v in 
     team_city.items()}
     
)
df["home_wins"]=(
    df["winner"]==df["home_team"]

)
home_advantage =(
    df.groupby("city")
    .agg(
        home_wins_percentage=(
            "home_wins",
            "mean"
            
        )
    )
    .sort_values(
        by="home_wins_percentage",
        ascending=False
    )
)
print(home_advantage*100)
# Out:
#            home_wins_percentage
# city
# Kolkata               31.578947
# Bangalore             25.806452
# Chennai               25.000000
# Delhi                 16.666667
# Mumbai                13.043478
# Jaipur                12.000000

# %%
#TASk 5 PLAYER ANALYSIS
pow=(
    df["player_of_match"]
    .value_counts()
)
print(pow)
# Out:
# player_of_match
# Player D    37
# Player C    32
# Player B    28
# Player A    28
# Player E    25
# Name: count, dtype: int64

# %%
#best Player Each Season
season_best=(
    df.groupby("season")[
         "player_of_match"
    ]
    .agg(lambda x:
x.value_counts().idxmax())        
)
print(season_best)
# Out:
# season
# 2018    Player D
# 2019    Player D
# 2020    Player A
# 2021    Player D
# 2022    Player C
# Name: player_of_match, dtype: object

# %%
#TRACK ONE PLAYER
virat =df[
    df["player_of_match"] == "player A"
]
print(virat)
print(df.to_string())
# Out:
# Empty DataFrame
# 134  135    2022    Chennai        Kolkata Knight Riders               Delhi Capitals        Kolkata Knight Riders           bat        Kolkata Knight Riders        Player B    Chennai Stadium   181        0            True          Chennai Super Kings      False
# 135  136    2022     Mumbai               Delhi Capitals        Kolkata Knight Riders               Delhi Capitals           bat               Delhi Capitals        Player D     Jaipur Stadium   217        8            True               Mumbai Indians      False
# 136  137    2022    Chennai          Chennai Super Kings               Delhi Capitals          Chennai Super Kings         field          Chennai Super Kings        Player B     Mumbai Stadium   198        7            True          Chennai Super Kings       True
# 137  138    2022     Jaipur             Rajasthan Royals          Chennai Super Kings          Chennai Super Kings         field          Chennai Super Kings        Player C      Delhi Stadium   167        9            True             Rajasthan Royals      False
# 138  139    2022     Mumbai  Royal Challengers Bangalore             Rajasthan Royals  Royal Challengers Bangalore         field  Royal Challengers Bangalore        Player E     Jaipur Stadium   212        2            True               Mumbai Indians      False
# 139  140    2022      Delhi               Mumbai Indians               Delhi Capitals               Mumbai Indians           bat               Mumbai Indians        Player C    Kolkata Stadium   216        8            True               Delhi Capitals      False
# 140  141    2022  Bangalore          Chennai Super Kings             Rajasthan Royals             Rajasthan Royals         field             Rajasthan Royals        Player D      Delhi Stadium   164        9            True  Royal Challengers Bangalore      False
# 141  142    2022  Bangalore             Rajasthan Royals          Chennai Super Kings          Chennai Super Kings           bat          Chennai Super Kings        Player B    Kolkata Stadium   121        6            True  Royal Challengers Bangalore      False
# 142  143    2022    Chennai        Kolkata Knight Riders               Mumbai Indians        Kolkata Knight Riders         field        Kolkata Knight Riders        Player E  Bangalore Stadium   189        2            True          Chennai Super Kings      False
# 143  144    2022     Jaipur  Royal Challengers Bangalore        Kolkata Knight Riders        Kolkata Knight Riders           bat        Kolkata Knight Riders        Player E     Jaipur Stadium   187        3            True             Rajasthan Royals      False
# 144  145    2022     Jaipur               Mumbai Indians               Delhi Capitals               Delhi Capitals           bat               Mumbai Indians        Player B     Jaipur Stadium   184        5           False             Rajasthan Royals      False
# 145  146    2022      Delhi               Mumbai Indians               Delhi Capitals               Mumbai Indians         field               Delhi Capitals        Player D  Bangalore Stadium   218        3           False               Delhi Capitals       True
# 146  147    2022  Bangalore          Chennai Super Kings             Rajasthan Royals             Rajasthan Royals           bat          Chennai Super Kings        Player B    Chennai Stadium   217        1           False  Royal Challengers Bangalore      False
# 147  148    2022      Delhi          Chennai Super Kings             Rajasthan Royals          Chennai Super Kings           bat          Chennai Super Kings        Player C    Kolkata Stadium   151        1            True               Delhi Capitals      False
# 148  149    2022     Jaipur               Delhi Capitals               Mumbai Indians               Delhi Capitals         field               Delhi Capitals        Player D      Delhi Stadium   140        4            True             Rajasthan Royals      False
# 149  150    2022  Bangalore               Delhi Capitals               Mumbai Indians               Delhi Capitals           bat               Delhi Capitals        Player B    Kolkata Stadium   157        1            True  Royal Challengers Bangalore      False

# %%
#Task 6 ADVANCED ANALYSIS
#1. Merge 
'''
matches_df = pd.read_csv("matches.csv")
deliveries_df = pd.read_csv("deliveries.csv")
merged = pd.merge(
    matches_df,
    deliveries_df,
    on="id"
)

#2. Total Runs by Batsman
batsman_runs = (
    merged.groupby("player_of_match")
          ["runs"]
          .sum()
)

print(batsman_runs)


#Top 10 Batsmen
top_batsmen = (
    batsman_runs
    .sort_values(ascending=False)
    .head(10)
)

print(top_batsmen)
'''
# Out:
# '\nmatches_df = pd.read_csv("matches.csv")\ndeliveries_df = pd.read_csv("deliveries.csv")\nmerged = pd.merge(\n    matches_df,\n    deliveries_df,\n    on="id"\n)\n\n#2. Total Runs by Batsman\nbatsman_runs = (\n    merged.groupby("player_of_match")\n          ["runs"]\n          .sum()\n)\n\nprint(batsman_runs)\n\n\n#Top 10 Batsmen\ntop_batsmen = (\n    batsman_runs\n    .sort_values(ascending=False)\n    .head(10)\n)\n\nprint(top_batsmen)\n'

# %%
#TASK 7: Filtering
#1. Mumbai Indians Matches
mi_matches = df.loc[
    (df["team1"] == "Mumbai Indians") |
    (df["team2"] == "Mumbai Indians")
]

print(mi_matches.to_string())
# Out:
#       id  season       city                        team1                        team2                  toss_winner toss_decision                       winner player_of_match              venue  runs  wickets  toss_match_win                    home_team  home_wins
# 0      1    2018    Chennai               Mumbai Indians          Chennai Super Kings               Mumbai Indians           bat               Mumbai Indians        Player C  Bangalore Stadium   207        4            True          Chennai Super Kings      False
# 6      7    2018     Jaipur               Mumbai Indians  Royal Challengers Bangalore  Royal Challengers Bangalore           bat  Royal Challengers Bangalore        Player D     Mumbai Stadium   181        7            True             Rajasthan Royals      False
# 7      8    2018     Mumbai        Kolkata Knight Riders               Mumbai Indians               Mumbai Indians         field               Mumbai Indians        Player D    Kolkata Stadium   160        0            True               Mumbai Indians       True
# 9     10    2018     Mumbai               Mumbai Indians        Kolkata Knight Riders        Kolkata Knight Riders         field               Mumbai Indians        Player D    Chennai Stadium   152        6           False               Mumbai Indians       True
# 10    11    2018  Bangalore        Kolkata Knight Riders               Mumbai Indians        Kolkata Knight Riders           bat        Kolkata Knight Riders        Player C     Mumbai Stadium   124        9            True  Royal Challengers Bangalore      False
# 12    13    2018      Delhi          Chennai Super Kings               Mumbai Indians          Chennai Super Kings         field          Chennai Super Kings        Player E  Bangalore Stadium   205        1            True               Delhi Capitals      False
# 18    19    2018  Bangalore               Mumbai Indians  Royal Challengers Bangalore  Royal Challengers Bangalore         field               Mumbai Indians        Player C     Mumbai Stadium   157        7           False  Royal Challengers Bangalore      False
# 19    20    2018     Mumbai               Mumbai Indians  Royal Challengers Bangalore               Mumbai Indians           bat               Mumbai Indians        Player D  Bangalore Stadium   189        2            True               Mumbai Indians       True
# 20    21    2018  Bangalore               Mumbai Indians          Chennai Super Kings               Mumbai Indians         field               Mumbai Indians        Player D     Mumbai Stadium   152        7            True  Royal Challengers Bangalore      False
# 24    25    2018  Bangalore               Mumbai Indians               Delhi Capitals               Mumbai Indians           bat               Delhi Capitals        Player E    Chennai Stadium   201        1           False  Royal Challengers Bangalore      False
# 31    32    2019     Mumbai               Mumbai Indians               Delhi Capitals               Delhi Capitals         field               Delhi Capitals        Player A     Mumbai Stadium   162        5            True               Mumbai Indians      False
# 32    33    2019      Delhi        Kolkata Knight Riders               Mumbai Indians        Kolkata Knight Riders         field               Mumbai Indians        Player B     Mumbai Stadium   155        3           False               Delhi Capitals      False
# 36    37    2019  Bangalore               Mumbai Indians  Royal Challengers Bangalore               Mumbai Indians         field               Mumbai Indians        Player B    Chennai Stadium   209        4            True  Royal Challengers Bangalore      False
# 40    41    2019    Kolkata               Mumbai Indians  Royal Challengers Bangalore               Mumbai Indians           bat  Royal Challengers Bangalore        Player E    Chennai Stadium   129        5           False        Kolkata Knight Riders      False
# 41    42    2019    Chennai               Mumbai Indians             Rajasthan Royals               Mumbai Indians         field             Rajasthan Royals        Player A      Delhi Stadium   123        7           False          Chennai Super Kings      False
# 43    44    2019    Chennai          Chennai Super Kings               Mumbai Indians               Mumbai Indians           bat          Chennai Super Kings        Player D      Delhi Stadium   132        1           False          Chennai Super Kings       True
# 44    45    2019      Delhi        Kolkata Knight Riders               Mumbai Indians               Mumbai Indians         field        Kolkata Knight Riders        Player B    Chennai Stadium   153        2           False               Delhi Capitals      False
# 53    54    2019     Mumbai               Mumbai Indians        Kolkata Knight Riders               Mumbai Indians         field        Kolkata Knight Riders        Player D     Mumbai Stadium   190        8           False               Mumbai Indians      False
# 54    55    2019      Delhi               Mumbai Indians  Royal Challengers Bangalore               Mumbai Indians         field               Mumbai Indians        Player C    Chennai Stadium   209        2            True               Delhi Capitals      False
# 56    57    2019     Mumbai             Rajasthan Royals               Mumbai Indians               Mumbai Indians           bat             Rajasthan Royals        Player A     Jaipur Stadium   125        9           False               Mumbai Indians      False
# 60    61    2020    Kolkata               Mumbai Indians  Royal Challengers Bangalore  Royal Challengers Bangalore           bat  Royal Challengers Bangalore        Player A    Kolkata Stadium   183        5            True        Kolkata Knight Riders      False
# 67    68    2020    Chennai               Mumbai Indians  Royal Challengers Bangalore               Mumbai Indians         field               Mumbai Indians        Player A     Jaipur Stadium   124        8            True          Chennai Super Kings      False
# 69    70    2020    Chennai        Kolkata Knight Riders               Mumbai Indians        Kolkata Knight Riders         field        Kolkata Knight Riders        Player A     Jaipur Stadium   216        7            True          Chennai Super Kings      False
# 73    74    2020     Jaipur  Royal Challengers Bangalore               Mumbai Indians  Royal Challengers Bangalore           bat               Mumbai Indians        Player E     Mumbai Stadium   131        9           False             Rajasthan Royals      False
# 76    77    2020      Delhi               Mumbai Indians               Delhi Capitals               Delhi Capitals         field               Delhi Capitals        Player C  Bangalore Stadium   126        2            True               Delhi Capitals       True
# 81    82    2020     Jaipur  Royal Challengers Bangalore               Mumbai Indians               Mumbai Indians           bat               Mumbai Indians        Player A  Bangalore Stadium   150        7            True             Rajasthan Royals      False
# 82    83    2020    Kolkata               Mumbai Indians          Chennai Super Kings          Chennai Super Kings           bat          Chennai Super Kings        Player D     Jaipur Stadium   213        7            True        Kolkata Knight Riders      False
# 87    88    2020  Bangalore               Mumbai Indians  Royal Challengers Bangalore  Royal Challengers Bangalore           bat               Mumbai Indians        Player B    Kolkata Stadium   218        2           False  Royal Challengers Bangalore      False
# 89    90    2020    Kolkata               Mumbai Indians          Chennai Super Kings          Chennai Super Kings           bat          Chennai Super Kings        Player E    Chennai Stadium   208        1            True        Kolkata Knight Riders      False
# 91    92    2021    Chennai               Delhi Capitals               Mumbai Indians               Delhi Capitals         field               Delhi Capitals        Player D      Delhi Stadium   152        3            True          Chennai Super Kings      False
# 100  101    2021  Bangalore        Kolkata Knight Riders               Mumbai Indians               Mumbai Indians           bat        Kolkata Knight Riders        Player D  Bangalore Stadium   170        5           False  Royal Challengers Bangalore      False
# 108  109    2021      Delhi        Kolkata Knight Riders               Mumbai Indians        Kolkata Knight Riders           bat        Kolkata Knight Riders        Player E  Bangalore Stadium   155        1            True               Delhi Capitals      False
# 116  117    2021  Bangalore               Mumbai Indians          Chennai Super Kings               Mumbai Indians         field               Mumbai Indians        Player C    Kolkata Stadium   178        6            True  Royal Challengers Bangalore      False
# 117  118    2021      Delhi               Mumbai Indians               Delhi Capitals               Delhi Capitals         field               Delhi Capitals        Player A    Chennai Stadium   155        3            True               Delhi Capitals       True
# 118  119    2021      Delhi          Chennai Super Kings               Mumbai Indians          Chennai Super Kings           bat               Mumbai Indians        Player B     Mumbai Stadium   145        1           False               Delhi Capitals      False
# 127  128    2022      Delhi             Rajasthan Royals               Mumbai Indians             Rajasthan Royals         field             Rajasthan Royals        Player C  Bangalore Stadium   158        3            True               Delhi Capitals      False
# 139  140    2022      Delhi               Mumbai Indians               Delhi Capitals               Mumbai Indians           bat               Mumbai Indians        Player C    Kolkata Stadium   216        8            True               Delhi Capitals      False
# 142  143    2022    Chennai        Kolkata Knight Riders               Mumbai Indians        Kolkata Knight Riders         field        Kolkata Knight Riders        Player E  Bangalore Stadium   189        2            True          Chennai Super Kings      False
# 144  145    2022     Jaipur               Mumbai Indians               Delhi Capitals               Delhi Capitals           bat               Mumbai Indians        Player B     Jaipur Stadium   184        5           False             Rajasthan Royals      False
# 145  146    2022      Delhi               Mumbai Indians               Delhi Capitals               Mumbai Indians         field               Delhi Capitals        Player D  Bangalore Stadium   218        3           False               Delhi Capitals       True
# 148  149    2022     Jaipur               Delhi Capitals               Mumbai Indians               Delhi Capitals         field               Delhi Capitals        Player D      Delhi Stadium   140        4            True             Rajasthan Royals      False
# 149  150    2022  Bangalore               Delhi Capitals               Mumbai Indians               Delhi Capitals           bat               Delhi Capitals        Player B    Kolkata Stadium   157        1            True  Royal Challengers Bangalore      False

# %%
#2. Close Matches
close_matches = df.query(
    "runs < 10"
)

print(close_matches)
# Out:
# Empty DataFrame
# Columns: [id, season, city, team1, team2, toss_winner, toss_decision, winner, player_of_match, venue, runs, wickets, toss_match_win, home_team, home_wins]
# Index: []

# %%
#Specific Season
season_2020 = df.query(
    "season == 2020"
)

print(season_2020)
# Out:
#     id  season       city                        team1  \
# 60  61    2020    Kolkata               Mumbai Indians
# 61  62    2020      Delhi  Royal Challengers Bangalore
# 62  63    2020     Jaipur        Kolkata Knight Riders
# 63  64    2020    Chennai        Kolkata Knight Riders
# 64  65    2020      Delhi        Kolkata Knight Riders
# 65  66    2020    Chennai          Chennai Super Kings
# 66  67    2020     Mumbai          Chennai Super Kings
# 67  68    2020    Chennai               Mumbai Indians
# 68  69    2020     Jaipur        Kolkata Knight Riders
# 69  70    2020    Chennai        Kolkata Knight Riders
# 70  71    2020    Chennai               Delhi Capitals
# 66        Kolkata Knight Riders        Player B    Kolkata Stadium   214
# 67               Mumbai Indians        Player A     Jaipur Stadium   124
# 68        Kolkata Knight Riders        Player D    Chennai Stadium   157
# 69        Kolkata Knight Riders        Player A     Jaipur Stadium   216
# 70               Delhi Capitals        Player A    Chennai Stadium   136
# 71  Royal Challengers Bangalore        Player C  Bangalore Stadium   142
# 72             Rajasthan Royals        Player B      Delhi Stadium   170
# 73               Mumbai Indians        Player E     Mumbai Stadium   131
# 74        Kolkata Knight Riders        Player A     Mumbai Stadium   205
# 75        Kolkata Knight Riders        Player A  Bangalore Stadium   171
# 76               Delhi Capitals        Player C  Bangalore Stadium   126
# 77          Chennai Super Kings        Player A      Delhi Stadium   147
# 78        Kolkata Knight Riders        Player E    Kolkata Stadium   144
# 79               Delhi Capitals        Player A    Kolkata Stadium   202
# 80  Royal Challengers Bangalore        Player E     Mumbai Stadium   152
# 81               Mumbai Indians        Player A  Bangalore Stadium   150
# 82          Chennai Super Kings        Player D     Jaipur Stadium   213
# 83               Delhi Capitals        Player E    Kolkata Stadium   124
# 84               Delhi Capitals        Player E     Jaipur Stadium   130
# 85          Chennai Super Kings        Player B    Kolkata Stadium   121
# 86             Rajasthan Royals        Player C     Jaipur Stadium   214
# 87               Mumbai Indians        Player B    Kolkata Stadium   218
# 88  Royal Challengers Bangalore        Player D     Jaipur Stadium   154
# 89          Chennai Super Kings        Player E    Chennai Stadium   208
#
#     wickets  toss_match_win                    home_team  home_wins
# 60        5            True        Kolkata Knight Riders      False
# 61        1           False               Delhi Capitals      False
# 62        6            True             Rajasthan Royals      False
# 63        0            True          Chennai Super Kings      False
# 64        4            True               Delhi Capitals      False
# 65        8            True          Chennai Super Kings       True
# 66        7            True               Mumbai Indians      False
# 67        8            True          Chennai Super Kings      False
# 68        1            True             Rajasthan Royals      False
# 69        7            True          Chennai Super Kings      False
# 70        3           False          Chennai Super Kings      False
# 71        6           False  Royal Challengers Bangalore       True
# 72        2           False  Royal Challengers Bangalore      False
# 73        9           False             Rajasthan Royals      False
# 74        7            True               Mumbai Indians      False
# 75        7            True               Mumbai Indians      False
# 76        2            True               Delhi Capitals       True
# 77        9            True  Royal Challengers Bangalore      False
# 78        3            True               Mumbai Indians      False
# 79        9           False             Rajasthan Royals      False
# 80        4           False  Royal Challengers Bangalore       True
# 81        7            True             Rajasthan Royals      False
# 82        7            True        Kolkata Knight Riders      False
# 83        5            True          Chennai Super Kings      False
# 84        3           False               Mumbai Indians      False
# 85        7            True          Chennai Super Kings       True
# 86        0            True               Mumbai Indians      False
# 87        2           False  Royal Challengers Bangalore      False
# 88        4            True               Delhi Capitals      False
# 89        1            True        Kolkata Knight Riders      False

# %%
#TASK 8: Pivot Table
#1. Team vs Season Wins
pivot = pd.pivot_table(
    df,
    index="season",
    columns="winner",
    values="id",
    aggfunc="count"
)

print(pivot)
# Out:
# winner  Chennai Super Kings  Delhi Capitals  Kolkata Knight Riders  \
# season
# 2018                      5               6                      4
# 2019                      5               4                      4
# 2020                      6               5                      8
# 2021                      3               6                      9
# 2022                      7               6                      7
#
# winner  Mumbai Indians  Rajasthan Royals  Royal Challengers Bangalore
# season
# 2018                 6                 3                            6
# 2019                 3                 8                            6
# 2020                 4                 2                            5
# 2021                 2                 3                            7
# 2022                 2                 2                            6

# %%
#2. City vs Total Matches
city_matches = pd.pivot_table(
    df,
    index="city",
    values="id",
    aggfunc="count"
)

print(city_matches)
# Out:
#            id
# city
# Bangalore  31
# Chennai    28
# Delhi      24
# Jaipur     25
# Kolkata    19
# Mumbai     23

# %%
#TASK 9: Custom Logic
#Big Win Column
df["big_win"] = df["runs"].apply(
    lambda x:
    "Yes" if x > 180 else "No"
)

print(df[["runs", "big_win"]])
# Out:
#      runs big_win
# 0     207     Yes
# 1     140      No
# 2     179      No
# 3     208     Yes
# 4     127      No
# ..    ...     ...
# 145   218     Yes
# 146   217     Yes
# 147   151      No
# 148   140      No
# 149   157      No
#
# [150 rows x 2 columns]

# %%
#Toss Winner Match Win %
toss_win_percent = (
    df["toss_match_win"]
    .mean() * 100
)

print(toss_win_percent)
# Out:
# 62.0

# %%
#Bat First vs Chase Analysis
bat_first = (
    df.groupby("toss_decision")
      ["toss_match_win"]
      .mean() * 100
)

print(bat_first)
# Out:
# toss_decision
# bat      58.441558
# field    65.753425
# Name: toss_match_win, dtype: float64

# %%
print("""
1. Mumbai Indians is the most successful team.
2. Toss winners have higher winning probability.
3. Some cities show strong home advantage.
4. High-scoring matches usually cross 180 runs.
5. Certain players dominate Player of the Match awards.
""")
# Out:
# 1. Mumbai Indians is the most successful team.
# 2. Toss winners have higher winning probability.
# 3. Some cities show strong home advantage.
# 4. High-scoring matches usually cross 180 runs.
# 5. Certain players dominate Player of the Match awards.

# %%
import matplotlib.pyplot as plt

# Count matches per venue
newdf = df.groupby("venue")["id"].count().sort_values(ascending=False)

# Plot
newdf.plot(kind="bar", figsize=(10,5), color="skyblue")

plt.title("Number of Matches Played at Each Venue")
plt.xlabel("Venue")
plt.ylabel("Match Count")

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# Count matches per venue

# Plot
import matplotlib.pyplot as plt

df["toss_decision"].value_counts().plot(kind="bar",figsize=(6,4),color="skyblue")

plt.title("Toss Decisions")
plt.xlabel("Decision")
plt.ylabel("Count")
plt.show()

# %%
df["winner"].value_counts().plot(kind="pie",figsize=(8,8),color="b",autopct="%1.1f%%")
plt.title("winners in each match")
plt.xlabel("Teams")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
newdf = df.groupby("winner")["runs"].sum().sort_values(ascending=False)
print(newdf)
newdf.plot(marker="8",ms=20,mec = 'r', mfc = 'r')
plt.title("Total Runs by winning city ")
plt.xticks(rotation=45)

plt.show()
# Out:
# winner
# Kolkata Knight Riders          5389
# Royal Challengers Bangalore    5058
# Delhi Capitals                 4473
# Chennai Super Kings            4429
# Rajasthan Royals               2999
# Mumbai Indians                 2936
# Name: runs, dtype: int64

# %%
newdf=df.groupby("winner")["wickets"].sum().sort_values(ascending=False)
print(newdf)
newdf.plot(marker="8",ms=20,mec = 'r', mfc = 'r')
plt.title("Total wickets by winning city ")
plt.xticks(rotation=45)

plt.show()
# Out:
# winner
# Kolkata Knight Riders          161
# Royal Challengers Bangalore    157
# Delhi Capitals                 120
# Chennai Super Kings             83
# Mumbai Indians                  81
# Rajasthan Royals                74
# Name: wickets, dtype: int64

# %%
newdf=df.groupby("winner")["toss_winner"].count().sort_values(ascending=False)
print(newdf)
newdf.plot(kind="barh",color="orange")
plt.title("winner vs toss winner")
plt.xticks(rotation=45)

plt.show()
# Out:
# winner
# Kolkata Knight Riders          32
# Royal Challengers Bangalore    30
# Delhi Capitals                 27
# Chennai Super Kings            26
# Rajasthan Royals               18
# Mumbai Indians                 17
# Name: toss_winner, dtype: int64

# %%
import matplotlib.pyplot as plt

# -----------------------------
# DATA PREPARATION
# -----------------------------

# 1. Matches at each venue
venue_matches = df.groupby("venue")["id"].count().sort_values(ascending=False)

# 2. Toss decisions
toss_decision = df["toss_decision"].value_counts()

# 3. Match winners
winner_count = df["winner"].value_counts()

# 4. Total runs by winning team
runs_by_winner = df.groupby("winner")["runs"].sum().sort_values(ascending=False)

# 5. Total wickets by winning team
wickets_by_winner = df.groupby("winner")["wickets"].sum().sort_values(ascending=False)

# 6. Toss winner = Match winner
toss_vs_winner = (df["toss_winner"] == df["winner"]).value_counts()

# -----------------------------
# DASHBOARD LAYOUT
# -----------------------------

plt.figure(figsize=(20, 15))

# -----------------------------
# 1. VENUE MATCHES
# -----------------------------
plt.subplot(2, 3, 1)

venue_matches.plot(
    kind="bar",
    color="skyblue",
    edgecolor="black"
)

plt.title("Matches Played at Each Venue")
plt.xlabel("Venue")
plt.ylabel("Match Count")
plt.xticks(rotation=45)

# -----------------------------
# 2. TOSS DECISION
# -----------------------------
plt.subplot(2, 3, 2)

toss_decision.plot(
    kind="bar",
    color=["orange", "green"],
    edgecolor="black"
)

plt.title("Toss Decisions")
plt.xlabel("Decision")
plt.ylabel("Count")
plt.xticks(rotation=0)

# -----------------------------
# 3. WINNER DISTRIBUTION
# -----------------------------
plt.subplot(2, 3, 3)

winner_count.plot(
    kind="pie",
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Match Winners Distribution")
plt.ylabel("")

# -----------------------------
# 4. RUNS BY WINNING TEAM
# -----------------------------
plt.subplot(2, 3, 4)

runs_by_winner.plot(
    marker="o",
    linewidth=3,
    color="red"
)

plt.title("Total Runs by Winning Team")
plt.xlabel("Teams")
plt.ylabel("Runs")
plt.xticks(rotation=45)

# -----------------------------
# 5. WICKETS BY WINNING TEAM
# -----------------------------
plt.subplot(2, 3, 5)

wickets_by_winner.plot(
    marker="D",
    linewidth=3,
    color="purple"
)

plt.title("Total Wickets by Winning Team")
plt.xlabel("Teams")
plt.ylabel("Wickets")
plt.xticks(rotation=45)

# -----------------------------
# 6. TOSS WINNER VS MATCH WINNER
# -----------------------------
plt.subplot(2, 3, 6)

toss_vs_winner.index = ["Different", "Same"]

toss_vs_winner.plot(kind="barh",color=["tomato", "lightgreen"],edgecolor="black")

plt.title("Toss Winner vs Match Winner")
plt.xlabel("Count")
plt.ylabel("Result")

# -----------------------------
# FINAL TOUCH
# -----------------------------
plt.tight_layout()

plt.show()
