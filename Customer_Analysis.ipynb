# %%
#Project Data Analysis
#1.Load Data
#sub Q
#Display first 10 rows
#Display last 5 rows

import pandas as pd
df=pd.read_csv("customers-100 (2).csv")
print(df.head(10))
print(df.tail(5))
# Out:
#    Index Customer Id First Name Last Name     Company       City Country  \
# 0      1    CUST1001      Aarav    Sharma    TechNova     Mumbai   India
# 1      2    CUST1002       Diya     Patel    DataSoft      Delhi   India
# 2      3    CUST1003     Vihaan     Mehta   CloudCore       Pune   India
# 3      4    CUST1004      Anaya     Reddy   ByteWorks    Chennai   India
# 4      5    CUST1005      Arjun    Kapoor     NextGen  Bangalore   India
# 5      6    CUST1006       Isha     Joshi   AlphaTech  Hyderabad   India
# 6      7    CUST1007      Kabir     Verma  VisionSoft    Kolkata   India
# 7      8    CUST1008      Meera      Nair     DataHub  Ahmedabad   India
# 8     11    CUST1011     Aditya     Singh    TechNova    Lucknow   India
# 9      9    CUST1009      Rohan     Desai     Innovix      Surat   India
#
#       Phone 1     Phone 2                     Email Subscription Date  \
# 0  9876500011  9122200011    aarav.sharma@gmail.com        05-01-2024
# 1  9876500012  9122200012      diya.patel@yahoo.com        06-01-2024
# 2  9876500013  9122200013  vihaan.mehta@outlook.com        07-01-2024
# 3  9876500014  9122200014     anaya.reddy@gmail.com        08-01-2024
# 4  9876500015  9122200015    arjun.kapoor@gmail.com        09-01-2024
# 5  9876500016  9122200016      isha.joshi@yahoo.com        10-01-2024
# 6  9876500017  9122200017     kabir.verma@gmail.com        11-01-2024
# 7  9876500018  9122200018      meevi.iyer@yahoo.com        14-01-2024
# 8  9876500021  9122200021     adra.nair@outlook.com        12-01-2024
# 9  9876500019  9122200019     rohan.desai@gmail.com        13-01-2024
#
#               Website
# 0    www.technova.com
# 1     www.datasoft.in
# 2   www.cloudcore.net
# 3   www.byteworks.org
# 4     www.nextgen.com
# 5    www.alphatech.in
# 6  www.visionsoft.com
# 7     www.softedge.in
# 8     www.datahub.net
# 9     www.innovix.org
#     Index Customer Id First Name Last Name     Company       City Country  \
# 95     96    CUST1096    Saanika       Dua   AlphaTech  Ahmedabad   India
# 96     97    CUST1097     Rehaan    Luthra  VisionSoft      Surat   India
# 97     98    CUST1098      Kiara     Monga     DataHub     Jaipur   India
# 98     99    CUST1099      Advik     Sidhu     Innovix    Lucknow   India
# 99    100    CUST1100    Samaira   Khattar    SoftEdge     Mumbai   India
#
#        Phone 1     Phone 2                      Email Subscription Date  \
# 95  9876500106  9122200106      saanika.dua@yahoo.com        10-04-2024
# 96  9876500107  9122200107    rehaan.luthra@gmail.com        11-04-2024
# 97  9876500108  9122200108      kiara.monga@gmail.com        12-04-2024
# 98  9876500109  9122200109      advik.sidhu@yahoo.com        13-04-2024
# 99  9876500110  9122200110  samaira.khattar@gmail.com        14-04-2024
#
#                Website
# 95    www.alphatech.in
# 96  www.visionsoft.com
# 97     www.datahub.net
# 98     www.innovix.org
# 99     www.softedge.in

# %%
#2.Dataset Information
# find
#find Total Rows and columns
print(df.shape)

#Column names
print(df.axes)#print(df.columns)

#Data types
print(df.dtypes)

#Missing alues
print(df.isnull().sum())
# Out:
# (100, 12)
# [RangeIndex(start=0, stop=100, step=1), Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='object')]
# Index                 int64
# Customer Id          object
# First Name           object
# Last Name            object
# Company              object
# City                 object
# Country              object
# Phone 1               int64
# Phone 2               int64
# Email                object
# Subscription Date    object
# Website              object
# dtype: object
# Index                0
# Customer Id          0
# First Name           0
# Last Name            0
# Company              0
# City                 0
# Country              0
# Phone 1              0
# Phone 2              0
# Email                0
# Subscription Date    0
# Website              0
# dtype: int64

# %%
#3. Customer Analysis

#1.Count total customers.
#print("Total customers: ",df["Index"].count())
#OR
print("Total Customer: ",len(df))

#2.Count unique cities.
print("unique cities: ",df['City'].nunique())
#OR
# print(df["City"].value_counts())

#3.Count unique countries.
print("unique countries: ",df['Country'].nunique())
#OR
#print(df["Country"].value_counts())

#4.Count unique companies.
# print(df["Company"].value_counts())
#OR 
print("unique companies",df['Company'].nunique())
# Out:
# Total Customer:  100
# unique cities:  11
# unique countries:  1
# unique companies 13

# %%
#4. Filtering Data

#Show customers:

#a.From India
newdf=df[df["Country"]=="India"]
print(newdf)
# Out:
#     Index Customer Id First Name Last Name     Company       City Country  \
# 0       1    CUST1001      Aarav    Sharma    TechNova     Mumbai   India
# 1       2    CUST1002       Diya     Patel    DataSoft      Delhi   India
# 2       3    CUST1003     Vihaan     Mehta   CloudCore       Pune   India
# 3       4    CUST1004      Anaya     Reddy   ByteWorks    Chennai   India
# 4       5    CUST1005      Arjun    Kapoor     NextGen  Bangalore   India
# ..    ...         ...        ...       ...         ...        ...     ...
# 95     96    CUST1096    Saanika       Dua   AlphaTech  Ahmedabad   India
# 96     97    CUST1097     Rehaan    Luthra  VisionSoft      Surat   India
# 97     98    CUST1098      Kiara     Monga     DataHub     Jaipur   India
# 98     99    CUST1099      Advik     Sidhu     Innovix    Lucknow   India
# 99    100    CUST1100    Samaira   Khattar    SoftEdge     Mumbai   India
#
#        Phone 1     Phone 2                      Email Subscription Date  \
# 0   9876500011  9122200011     aarav.sharma@gmail.com        05-01-2024
# 1   9876500012  9122200012       diya.patel@yahoo.com        06-01-2024
# 2   9876500013  9122200013   vihaan.mehta@outlook.com        07-01-2024
# 3   9876500014  9122200014      anaya.reddy@gmail.com        08-01-2024
# 4   9876500015  9122200015     arjun.kapoor@gmail.com        09-01-2024
# ..         ...         ...                        ...               ...
# 95  9876500106  9122200106      saanika.dua@yahoo.com        10-04-2024
# 96  9876500107  9122200107    rehaan.luthra@gmail.com        11-04-2024
# 97  9876500108  9122200108      kiara.monga@gmail.com        12-04-2024
# 98  9876500109  9122200109      advik.sidhu@yahoo.com        13-04-2024
# 99  9876500110  9122200110  samaira.khattar@gmail.com        14-04-2024
#
#                Website
# 0     www.technova.com
# 1      www.datasoft.in
# 2    www.cloudcore.net
# 3    www.byteworks.org
# 4      www.nextgen.com
# ..                 ...
# 95    www.alphatech.in
# 96  www.visionsoft.com
# 97     www.datahub.net
# 98     www.innovix.org
# 99     www.softedge.in
#
# [100 rows x 12 columns]

# %%
#b.From Mumbai
newdf=df[df["City"]=="Mumbai"]
print(newdf)
# Out:
#     Index Customer Id First Name Last Name     Company    City Country  \
# 0       1    CUST1001      Aarav    Sharma    TechNova  Mumbai   India
# 11     12    CUST1012      Kiara  Malhotra    DataSoft  Mumbai   India
# 22     23    CUST1023      Kunal      Jain   CloudCore  Mumbai   India
# 33     34    CUST1034       Sara   Trivedi   ByteWorks  Mumbai   India
# 44     45    CUST1045       Aman       Das     NextGen  Mumbai   India
# 55     56    CUST1056     Trisha    Pathak   AlphaTech  Mumbai   India
# 66     67    CUST1067     Raghav    Talwar  VisionSoft  Mumbai   India
# 77     78    CUST1078    Shanaya    Arneja     DataHub  Mumbai   India
# 88     89    CUST1089      Viraj     Sethi     Innovix  Mumbai   India
# 99    100    CUST1100    Samaira   Khattar    SoftEdge  Mumbai   India
#
#        Phone 1     Phone 2                      Email Subscription Date  \
# 0   9876500011  9122200011     aarav.sharma@gmail.com        05-01-2024
# 11   876500022  9122200022   kiara.malhotra@gmail.com        16-01-2024
# 22  9876500033  9122200033       kunal.jain@gmail.com        27-01-2024
# 33  9876500044  9122200044     sara.trivedi@yahoo.com        07-02-2024
# 44  9876500055  9122200055         aman.das@gmail.com        18-02-2024
# 55  9876500066  9122200066    trisha.pathak@yahoo.com        01-03-2024
# 66  9876500077  9122200077    raghav.talwar@gmail.com        12-03-2024
# 77  9876500088  9122200088   shanaya.arneja@gmail.com        23-03-2024
# 88  9876500099  9122200099      viraj.sethi@yahoo.com        03-04-2024
# 99  9876500110  9122200110  samaira.khattar@gmail.com        14-04-2024
#
#                Website
# 0     www.technova.com
# 11     www.datasoft.in
# 22   www.cloudcore.net
# 33   www.byteworks.org
# 44     www.nextgen.com
# 55    www.alphatech.in
# 66  www.visionsoft.com
# 77     www.datahub.net
# 88     www.innovix.org
# 99     www.softedge.in

# %%
#c.Having Gmail accounts
newdf=df[df["Email"].str.contains("gmail.com",na=False)]
print(newdf)
# Out:
#     Index Customer Id First Name   Last Name     Company       City Country  \
# 0       1    CUST1001      Aarav      Sharma    TechNova     Mumbai   India
# 3       4    CUST1004      Anaya       Reddy   ByteWorks    Chennai   India
# 4       5    CUST1005      Arjun      Kapoor     NextGen  Bangalore   India
# 6       7    CUST1007      Kabir       Verma  VisionSoft    Kolkata   India
# 9       9    CUST1009      Rohan       Desai     Innovix      Surat   India
# 10     10    CUST1010     Saanvi        Iyer    SoftEdge     Jaipur   India
# 11     12    CUST1012      Kiara    Malhotra    DataSoft     Mumbai   India
# 12     13    CUST1013       Yash       Gupta   CloudCore      Delhi   India
# 13     14    CUST1014       Myra      Chopra   ByteWorks       Pune   India
# 16     18    CUST1018       Pari      Saxena  DataHuTech  Bangalore   India
# 17     17    CUST1017    Reyansh         Rao    VisionSb    Kolkata   India
# 18     19    CUST1019      Dhruv      Tiwari     Innovix  Ahmedabad   India
# 20     21    CUST1021      Aryan       Yadav    TechNova     Jaipur   India
# 22     23    CUST1023      Kunal        Jain   CloudCore     Mumbai   India
# 24     25    CUST1025  Siddharth      Pillai     NextGen       Pune   India
# 25     26    CUST1026      Anika      Khanna   AlphaTech    Chennai   India
# 27     28    CUST1028       Riya       Sethi     DataHub  Hyderabad   India
# 28     29    CUST1029    Krishna     Dwivedi     Innovix    Kolkata   India
# 30     31    CUST1031      Harsh        Vyas    TechNova      Surat   India
# 32     33    CUST1033        Dev      Bhatia   CloudCore    Lucknow   India
# 34     35    CUST1035     Nikhil        Soni     NextGen      Delhi   India
# 35     36    CUST1036      Kavya    Banerjee   AlphaTech       Pune   India
# 37     38    CUST1038        Ira       Dutta     DataHub  Bangalore   India
# 38     39    CUST1039     Pranav       Ghosh     Innovix  Hyderabad   India
# 40     41    CUST1041      Ritik      Thomas    TechNova  Ahmedabad   India
# 42     43    CUST1043     Tanmay       Naidu   CloudCore     Jaipur   India
# 44     45    CUST1045       Aman         Das     NextGen     Mumbai   India
# 45     46    CUST1046       Rhea         Roy   AlphaTech      Delhi   India
# 47     48    CUST1048       Neha         Pal     DataHub    Chennai   India
# 48     49    CUST1049        Raj  Chatterjee     Innovix  Bangalore   India
# 50     51    CUST1051     Vedant       Malik    TechNova    Kolkata   India
# 52     53    CUST1053      Ayush      Bindra   CloudCore      Surat   India
# 54     55    CUST1055      Karan         Lal     NextGen    Lucknow   India
# 56     57    CUST1057   Shivansh      Mathur  VisionSoft      Delhi   India
# 57     58    CUST1058   Priyanka       Kohli     DataHub       Pune   India
# 59     60    CUST1060     Muskan        Bedi    SoftEdge  Bangalore   India
# 60     61    CUST1061     Yuvraj   Sabharwal    TechNova  Hyderabad   India
# 62     63    CUST1063      Tejas        Puri   CloudCore  Ahmedabad   India
# 64     65    CUST1065      Parth      Dhawan     NextGen     Jaipur   India
# 66     67    CUST1067     Raghav      Talwar  VisionSoft     Mumbai   India
# 67     68    CUST1068     Khushi       Bajaj     DataHub      Delhi   India
# 69     70    CUST1070      Sneha       Walia    SoftEdge    Chennai   India
# 70     71    CUST1071     Vivaan       Ahuja    TechNova  Bangalore   India
# 72     73    CUST1073      Ronit       Sarin   CloudCore    Kolkata   India
# 74     75    CUST1075      Samar      Gulati     NextGen      Surat   India
# 76     77    CUST1077      Ayaan      Oberoi  VisionSoft    Lucknow   India
# 77     78    CUST1078    Shanaya      Arneja     DataHub     Mumbai   India
# 79     80    CUST1080    Anushka      Chadha    SoftEdge       Pune   India
# 80     81    CUST1081    Devansh    Sachdeva    TechNova    Chennai   India
# 82     83    CUST1083   Rudransh       Saini   CloudCore  Hyderabad   India
# 84     85    CUST1085    Lakshya       Bagga     NextGen  Ahmedabad   India
# 86     87    CUST1087      Abeer      Kakkar  VisionSoft     Jaipur   India
# 87     88    CUST1088       Ruhi       Arora     DataHub    Lucknow   India
# 89     90    CUST1090      Mehak       Pahwa    SoftEdge      Delhi   India
# 90     91    CUST1091    Shaurya      Bhasin    TechNova       Pune   India
# 92     93    CUST1093      Daksh    Randhawa   CloudCore  Bangalore   India
# 94     95    CUST1095      Arush       Chugh     NextGen    Kolkata   India
# 96     97    CUST1097     Rehaan      Luthra  VisionSoft      Surat   India
# 97     98    CUST1098      Kiara       Monga     DataHub     Jaipur   India
# 99    100    CUST1100    Samaira     Khattar    SoftEdge     Mumbai   India
#
#         Phone 1     Phone 2                       Email Subscription Date  \
# 0    9876500011  9122200011      aarav.sharma@gmail.com        05-01-2024
# 3    9876500014  9122200014       anaya.reddy@gmail.com        08-01-2024
# 4    9876500015  9122200015      arjun.kapoor@gmail.com        09-01-2024
# 6    9876500017  9122200017       kabir.verma@gmail.com        11-01-2024
# 9    9876500019  9122200019       rohan.desai@gmail.com        13-01-2024
# 10   9876500020  9122200020    saanitya.singh@gmail.com        15-01-2024
# 11    876500022  9122200022    kiara.malhotra@gmail.com        16-01-2024
# 12  98765040023  9122200023        yash.gupta@gmail.com        17-01-2024
# 13   9876500024  9122200024       myra.chopra@gmail.com        18-01-2024
# 16   9876500026  9122200026     aadhya.mishra@gmail.com        20-01-2024
# 17   9876500028  9122200028       pari.saxena@gmail.com        22-01-2024
# 18   9876500029  9122200029      dhruv.tiwari@gmail.com        23-01-2024
# 20   9876500031  9122200031       aryan.yadav@gmail.com        25-01-2024
# 22   9876500033  9122200033        kunal.jain@gmail.com        27-01-2024
# 24   9876500035  9122200035  siddharth.pillai@gmail.com        29-01-2024
# 25   9876500036  9122200036      anika.khanna@gmail.com        30-01-2024
# 27   9876500038  9122200038        riya.sethi@gmail.com        01-02-2024
# 28   9876500039  9122200039   krishna.dwivedi@gmail.com        02-02-2024
# 30   9876500041  9122200041        harsh.vyas@gmail.com        04-02-2024
# 32   9876500043  9122200043        dev.bhatia@gmail.com        06-02-2024
# 34   9876500045  9122200045       nikhil.soni@gmail.com        08-02-2024
# 35   9876500046  9122200046    kavya.banerjee@gmail.com        09-02-2024
# 37   9876500048  9122200048         ira.dutta@gmail.com        11-02-2024
# 38   9876500049  9122200049      pranav.ghosh@gmail.com        12-02-2024
# 40   9876500051  9122200051      ritik.thomas@gmail.com        14-02-2024
# 42   9876500053  9122200053      tanmay.naidu@gmail.com        16-02-2024
# 44   9876500055  9122200055          aman.das@gmail.com        18-02-2024
# 45   9876500056  9122200056          rhea.roy@gmail.com        19-02-2024
# 47   9876500058  9122200058          neha.pal@gmail.com        21-02-2024
# 48   9876500059  9122200059    raj.chatterjee@gmail.com        22-02-2024
# 50   9876500061  9122200061      vedant.malik@gmail.com        24-02-2024
# 52   9876500063  9122200063      ayush.bindra@gmail.com        26-02-2024
# 54   9876500065  9122200065         karan.lal@gmail.com        28-02-2024
# 56   9876500067  9122200067   shivansh.mathur@gmail.com        02-03-2024
# 57   9876500068  9122200068    priyanka.kohli@gmail.com        03-03-2024
# 59   9876500070  9122200070       muskan.bedi@gmail.com        05-03-2024
# 60   9876500071  9122200071  yuvraj.sabharwal@gmail.com        06-03-2024
# 62   9876500073  9122200073        tejas.puri@gmail.com        08-03-2024
# 64   9876500075  9122200075      parth.dhawan@gmail.com        10-03-2024
# 66   9876500077  9122200077     raghav.talwar@gmail.com        12-03-2024
# 67   9876500078  9122200078      khushi.bajaj@gmail.com        13-03-2024
# 69   9876500080  9122200080       sneha.walia@gmail.com        15-03-2024
# 70   9876500081  9122200081      vivaan.ahuja@gmail.com        16-03-2024
# 72   9876500083  9122200083       ronit.sarin@gmail.com        18-03-2024
# 74   9876500085  9122200085      samar.gulati@gmail.com        20-03-2024
# 76   9876500087  9122200087      ayaan.oberoi@gmail.com        22-03-2024
# 77   9876500088  9122200088    shanaya.arneja@gmail.com        23-03-2024
# 79   9876500090  9122200090    anushka.chadha@gmail.com        25-03-2024
# 80   9876500091  9122200091  devansh.sachdeva@gmail.com        26-03-2024
# 82   9876500093  9122200093    rudransh.saini@gmail.com        28-03-2024
# 84   9876500095  9122200095     lakshya.bagga@gmail.com        30-03-2024
# 86   9876500097  9122200097      abeer.kakkar@gmail.com        01-04-2024
# 87   9876500098  9122200098        ruhi.arora@gmail.com        02-04-2024
# 89   9876500100  9122200100       mehak.pahwa@gmail.com        04-04-2024
# 90   9876500101  9122200101    shaurya.bhasin@gmail.com        05-04-2024
# 92   9876500103  9122200103    daksh.randhawa@gmail.com        07-04-2024
# 94   9876500105  9122200105       arush.chugh@gmail.com        09-04-2024
# 96   9876500107  9122200107     rehaan.luthra@gmail.com        11-04-2024
# 97   9876500108  9122200108       kiara.monga@gmail.com        12-04-2024
# 99   9876500110  9122200110   samaira.khattar@gmail.com        14-04-2024
#
#                Website
# 0     www.technova.com
# 3    www.byteworks.org
# 4      www.nextgen.com
# 6   www.visionsoft.com
# 9      www.innovix.org
# 10    www.technova.com
# 11     www.datasoft.in
# 12   www.cloudcore.net
# 13   www.byteworks.org
# 16    www.alphatech.in
# 17     www.datahub.net
# 18     www.innovix.org
# 20    www.technova.com
# 22   www.cloudcore.net
# 24     www.nextgen.com
# 25    www.alphatech.in
# 27     www.datahub.net
# 28     www.innovix.org
# 30    www.technova.com
# 32   www.cloudcore.net
# 34     www.nextgen.com
# 35    www.alphatech.in
# 37     www.datahub.net
# 38     www.innovix.org
# 40    www.technova.com
# 42   www.cloudcore.net
# 44     www.nextgen.com
# 45    www.alphatech.in
# 47     www.datahub.net
# 48     www.innovix.org
# 50    www.technova.com
# 52   www.cloudcore.net
# 54     www.nextgen.com
# 56  www.visionsoft.com
# 57     www.datahub.net
# 59     www.softedge.in
# 60    www.technova.com
# 62   www.cloudcore.net
# 64     www.nextgen.com
# 66  www.visionsoft.com
# 67     www.datahub.net
# 69     www.softedge.in
# 70    www.technova.com
# 72   www.cloudcore.net
# 74     www.nextgen.com
# 76  www.visionsoft.com
# 77     www.datahub.net
# 79     www.softedge.in
# 80    www.technova.com
# 82   www.cloudcore.net
# 84     www.nextgen.com
# 86  www.visionsoft.com
# 87     www.datahub.net
# 89     www.softedge.in
# 90    www.technova.com
# 92   www.cloudcore.net
# 94     www.nextgen.com
# 96  www.visionsoft.com
# 97     www.datahub.net
# 99     www.softedge.in

# %%
# Convert Subscription Date to datetime

df['Subscription Date'] = pd.to_datetime(df['Subscription Date'],format="mixed")
print(df['Subscription Date'].dtype)

#d.Subscription after 2024
sub_after_2024 = df[df['Subscription Date'].dt.year > 2024]
print("\nSUBSCRIPTIONS AFTER 2024")
print(sub_after_2024)
# Out:
# datetime64[ns]
#
# SUBSCRIPTIONS AFTER 2024
# Empty DataFrame
# Columns: [Index, Customer Id, First Name, Last Name, Company, City, Country, Phone 1, Phone 2, Email, Subscription Date, Website, Full Name, Email Domain, Website Domain, Year, Month]
# Index: []

# %%
#5. Sorting Data

#Q.Sort customers by:

#a.First Name
print(df.sort_values(by="First Name"))
# Out:
#     Index Customer Id First Name  Last Name     Company       City Country  \
# 15     16    CUST1016     Aadhya     Mishra    Alphaoft  Hyderabad   India
# 0       1    CUST1001      Aarav     Sharma    TechNova     Mumbai   India
# 91     92    CUST1092     Aarohi      Kalra    DataSoft    Chennai   India
# 86     87    CUST1087      Abeer     Kakkar  VisionSoft     Jaipur   India
# 8      11    CUST1011     Aditya      Singh    TechNova    Lucknow   India
# ..    ...         ...        ...        ...         ...        ...     ...
# 88     89    CUST1089      Viraj      Sethi     Innovix     Mumbai   India
# 70     71    CUST1071     Vivaan      Ahuja    TechNova  Bangalore   India
# 12     13    CUST1013       Yash      Gupta   CloudCore      Delhi   India
# 60     61    CUST1061     Yuvraj  Sabharwal    TechNova  Hyderabad   India
# 43     44    CUST1044       Zoya     George   ByteWorks    Lucknow   India
#
#         Phone 1     Phone 2                       Email Subscription Date  \
# 15   9876500027  9122200027       reyansh.rao@yahoo.com        2024-01-21
# 0    9876500011  9122200011      aarav.sharma@gmail.com        2024-05-01
# 91   9876500102  9122200102      aarohi.kalra@yahoo.com        2024-06-04
# 86   9876500097  9122200097      abeer.kakkar@gmail.com        2024-01-04
# 8    9876500021  9122200021       adra.nair@outlook.com        2024-12-01
# ..          ...         ...                         ...               ...
# 88   9876500099  9122200099       viraj.sethi@yahoo.com        2024-03-04
# 70   9876500081  9122200081      vivaan.ahuja@gmail.com        2024-03-16
# 12  98765040023  9122200023        yash.gupta@gmail.com        2024-01-17
# 60   9876500071  9122200071  yuvraj.sabharwal@gmail.com        2024-06-03
# 43   9876500054  9122200054       zoya.george@yahoo.com        2024-02-17
#
#                Website
# 15  www.visionsoft.com
# 0     www.technova.com
# 91     www.datasoft.in
# 86  www.visionsoft.com
# 8      www.datahub.net
# ..                 ...
# 88     www.innovix.org
# 70    www.technova.com
# 12   www.cloudcore.net
# 60    www.technova.com
# 43   www.byteworks.org
#
# [100 rows x 12 columns]

# %%
#b.by Country
print(df.sort_values(by="Country"))
# Out:
#     Index Customer Id First Name Last Name     Company       City Country  \
# 0       1    CUST1001      Aarav    Sharma    TechNova     Mumbai   India
# 72     73    CUST1073      Ronit     Sarin   CloudCore    Kolkata   India
# 71     72    CUST1072      Tanya    Grover    DataSoft  Hyderabad   India
# 70     71    CUST1071     Vivaan     Ahuja    TechNova  Bangalore   India
# 69     70    CUST1070      Sneha     Walia    SoftEdge    Chennai   India
# ..    ...         ...        ...       ...         ...        ...     ...
# 28     29    CUST1029    Krishna   Dwivedi     Innovix    Kolkata   India
# 27     28    CUST1028       Riya     Sethi     DataHub  Hyderabad   India
# 26     27    CUST1027      Manav     Arora  VisionSoft  Bangalore   India
# 36     37    CUST1037      Omkar    Shetty  VisionSoft    Chennai   India
# 99    100    CUST1100    Samaira   Khattar    SoftEdge     Mumbai   India
#
#        Phone 1     Phone 2                      Email Subscription Date  \
# 0   9876500011  9122200011     aarav.sharma@gmail.com        2024-05-01
# 72  9876500083  9122200083      ronit.sarin@gmail.com        2024-03-18
# 71  9876500082  9122200082     tanya.grover@yahoo.com        2024-03-17
# 70  9876500081  9122200081     vivaan.ahuja@gmail.com        2024-03-16
# 69  9876500080  9122200080      sneha.walia@gmail.com        2024-03-15
# ..         ...         ...                        ...               ...
# 28  9876500039  9122200039  krishna.dwivedi@gmail.com        2024-02-02
# 27  9876500038  9122200038       riya.sethi@gmail.com        2024-01-02
# 26  9876500037  9122200037      manav.arora@yahoo.com        2024-01-31
# 36  9876500047  9122200047     omkar.shetty@yahoo.com        2024-10-02
# 99  9876500110  9122200110  samaira.khattar@gmail.com        2024-04-14
#
#                Website
# 0     www.technova.com
# 72   www.cloudcore.net
# 71     www.datasoft.in
# 70    www.technova.com
# 69     www.softedge.in
# ..                 ...
# 28     www.innovix.org
# 27     www.datahub.net
# 26  www.visionsoft.com
# 36  www.visionsoft.com
# 99     www.softedge.in
#
# [100 rows x 12 columns]

# %%
#c.by Subscription Date
print(df.sort_values(by="Subscription Date"))
# Out:
#     Index Customer Id First Name Last Name     Company       City Country  \
# 27     28    CUST1028       Riya     Sethi     DataHub  Hyderabad   India
# 55     56    CUST1056     Trisha    Pathak   AlphaTech     Mumbai   India
# 86     87    CUST1087      Abeer    Kakkar  VisionSoft     Jaipur   India
# 9       9    CUST1009      Rohan     Desai     Innovix      Surat   India
# 7       8    CUST1008      Meera      Nair     DataHub  Ahmedabad   India
# ..    ...         ...        ...       ...         ...        ...     ...
# 96     97    CUST1097     Rehaan    Luthra  VisionSoft      Surat   India
# 8      11    CUST1011     Aditya     Singh    TechNova    Lucknow   India
# 38     39    CUST1039     Pranav     Ghosh     Innovix  Hyderabad   India
# 66     67    CUST1067     Raghav    Talwar  VisionSoft     Mumbai   India
# 97     98    CUST1098      Kiara     Monga     DataHub     Jaipur   India
#
#        Phone 1     Phone 2                    Email Subscription Date  \
# 27  9876500038  9122200038     riya.sethi@gmail.com        2024-01-02
# 55  9876500066  9122200066  trisha.pathak@yahoo.com        2024-01-03
# 86  9876500097  9122200097   abeer.kakkar@gmail.com        2024-01-04
# 9   9876500019  9122200019    rohan.desai@gmail.com        2024-01-13
# 7   9876500018  9122200018     meevi.iyer@yahoo.com        2024-01-14
# ..         ...         ...                      ...               ...
# 96  9876500107  9122200107  rehaan.luthra@gmail.com        2024-11-04
# 8   9876500021  9122200021    adra.nair@outlook.com        2024-12-01
# 38  9876500049  9122200049   pranav.ghosh@gmail.com        2024-12-02
# 66  9876500077  9122200077  raghav.talwar@gmail.com        2024-12-03
# 97  9876500108  9122200108    kiara.monga@gmail.com        2024-12-04
#
#                Website
# 27     www.datahub.net
# 55    www.alphatech.in
# 86  www.visionsoft.com
# 9      www.innovix.org
# 7      www.softedge.in
# ..                 ...
# 96  www.visionsoft.com
# 8      www.datahub.net
# 38     www.innovix.org
# 66  www.visionsoft.com
# 97     www.datahub.net
#
# [100 rows x 12 columns]

# %%
#🔹 Part B — Data Cleaning Questions
#6. Missing Data
#a.Find rows with missing email.
newdf=df[df["Email"].isnull()]
print(newdf)
#b.Replace missing phone numbers with "Not Available"
df["Phone 1"] = df["Phone 1"].fillna("Not Available")
print(df["Phone 1"])
df["Phone 2"] = df["Phone 2"].fillna("Not Available")
print(df["Phone 2"])
# Out:
# Empty DataFrame
# Columns: [Index, Customer Id, First Name, Last Name, Company, City, Country, Phone 1, Phone 2, Email, Subscription Date, Website, Full Name, Email Domain, Website Domain, Year, Month]
# Index: []
# 0     9876500011
# 1     9876500012
# 2     9876500013
# 3     9876500014
# 4     9876500015
#          ...
# 95    9876500106
# 96    9876500107
# 97    9876500108
# 98    9876500109
# 99    9876500110
# Name: Phone 1, Length: 100, dtype: object
# 0     9122200011
# 1     9122200012
# 2     9122200013
# 3     9122200014
# 4     9122200015
#          ...
# 95    9122200106
# 96    9122200107
# 97    9122200108
# 98    9122200109
# 99    9122200110
# Name: Phone 2, Length: 100, dtype: int64

# %%
#7. Duplicate Records
#a.Find duplicate customers.
print("\nDUPLICATE RECORDS")
print(df[df.duplicated()])

#b.Remove duplicates.
print(df.drop_duplicates)
#after removing
print(df.shape)
# Out:
# DUPLICATE RECORDS
# Empty DataFrame
# Columns: [Index, Customer Id, First Name, Last Name, Company, City, Country, Phone 1, Phone 2, Email, Subscription Date, Website, Full Name, Email Domain, Website Domain, Year, Month]
# Index: []
# <bound method DataFrame.drop_duplicates of     Index Customer Id First Name Last Name     Company       City Country  \
# 0       1    CUST1001      Aarav    Sharma    TechNova     Mumbai   India
# 1       2    CUST1002       Diya     Patel    DataSoft      Delhi   India
# 2       3    CUST1003     Vihaan     Mehta   CloudCore       Pune   India
# 3       4    CUST1004      Anaya     Reddy   ByteWorks    Chennai   India
# 4       5    CUST1005      Arjun    Kapoor     NextGen  Bangalore   India
# ..    ...         ...        ...       ...         ...        ...     ...
# 95     96    CUST1096    Saanika       Dua   AlphaTech  Ahmedabad   India
# 96     97    CUST1097     Rehaan    Luthra  VisionSoft      Surat   India
# 97     98    CUST1098      Kiara     Monga     DataHub     Jaipur   India
# 98     99    CUST1099      Advik     Sidhu     Innovix    Lucknow   India
# 99    100    CUST1100    Samaira   Khattar    SoftEdge     Mumbai   India
#
#        Phone 1     Phone 2                      Email Subscription Date  \
# 0   9876500011  9122200011     aarav.sharma@gmail.com        2024-05-01
# 1   9876500012  9122200012       diya.patel@yahoo.com        2024-06-01
# 2   9876500013  9122200013   vihaan.mehta@outlook.com        2024-07-01
# 3   9876500014  9122200014      anaya.reddy@gmail.com        2024-08-01
# 4   9876500015  9122200015     arjun.kapoor@gmail.com        2024-09-01
# ..         ...         ...                        ...               ...
# 95  9876500106  9122200106      saanika.dua@yahoo.com        2024-10-04
# 96  9876500107  9122200107    rehaan.luthra@gmail.com        2024-11-04
# 97  9876500108  9122200108      kiara.monga@gmail.com        2024-12-04
# 98  9876500109  9122200109      advik.sidhu@yahoo.com        2024-04-13
# 99  9876500110  9122200110  samaira.khattar@gmail.com        2024-04-14
#
#                Website        Full Name Email Domain Website Domain  Year  \
# 0     www.technova.com     Aarav Sharma    gmail.com            com  2024
# 1      www.datasoft.in       Diya Patel    yahoo.com             in  2024
# 2    www.cloudcore.net     Vihaan Mehta  outlook.com            net  2024
# 3    www.byteworks.org      Anaya Reddy    gmail.com            org  2024
# 4      www.nextgen.com     Arjun Kapoor    gmail.com            com  2024
# ..                 ...              ...          ...            ...   ...
# 95    www.alphatech.in      Saanika Dua    yahoo.com             in  2024
# 96  www.visionsoft.com    Rehaan Luthra    gmail.com            com  2024
# 97     www.datahub.net      Kiara Monga    gmail.com            net  2024
# 98     www.innovix.org      Advik Sidhu    yahoo.com            org  2024
# 99     www.softedge.in  Samaira Khattar    gmail.com             in  2024
#
#     Month
# 0       5
# 1       6
# 2       7
# 3       8
# 4       9
# ..    ...
# 95     10
# 96     11
# 97     12
# 98      4
# 99      4
#
# [100 rows x 17 columns]>
# (100, 17)

# %%
#8. Create New Columns

#Create:
#a.Full Name = First Name + Last Name
df["Full Name"]=df["First Name"] +" "+ df["Last Name"]
print(df["Full Name"])
# Out:
# 0        Aarav Sharma
# 1          Diya Patel
# 2        Vihaan Mehta
# 3         Anaya Reddy
# 4        Arjun Kapoor
#            ...
# 95        Saanika Dua
# 96      Rehaan Luthra
# 97        Kiara Monga
# 98        Advik Sidhu
# 99    Samaira Khattar
# Name: Full Name, Length: 100, dtype: object

# %%
#9. EMAIL DOMAIN ANALYSIS

#a. Extract domain

df['Email Domain'] = df['Email'].str.split('@').str[-1]
print(df['Email Domain'])

#b. Count domains
print(df['Email Domain'].value_counts())

#c. Gmail count
print((df['Email Domain'] == 'gmail.com').sum())

#d. Yahoo count
print((df['Email Domain'] == 'yahoo.com').sum())

#e. Outlook count
print((df['Email Domain'] == 'outlook.com').sum())
# Out:
# 0       gmail.com
# 1       yahoo.com
# 2     outlook.com
# 3       gmail.com
# 4       gmail.com
#          ...
# 95      yahoo.com
# 96      gmail.com
# 97      gmail.com
# 98      yahoo.com
# 99      gmail.com
# Name: Email Domain, Length: 100, dtype: object
# Email Domain
# gmail.com      60
# yahoo.com      29
# outlook.com    11
# Name: count, dtype: int64
# 60
# 29
# 11

# %%
#10. Website Analysis
#a.Count .com, .org, .net websites.
print("Webiste.com: ",df["Website"].str.contains(".com",na=False).sum())
print("Webiste.org: ",df["Website"].str.contains(".org",na=False).sum())
print("Webiste.net: ",df["Website"].str.contains(".net",na=False).sum())
#print("Webiste.in: ",df["Website"].str.contains(".in",na=False).str[-1].sum())

#b.Find most common website domain.
df['Website Domain'] = df['Website'].str.split('.').str[-1] 
print(df['Website Domain'].mode())
# Out:
# Webiste.com:  30
# Webiste.org:  20
# Webiste.net:  20
# 0    com
# 1     in
# Name: Website Domain, dtype: object

# %%
#11. Country-wise Customer Count

#a.Find number of customers in each country.
country_count=df.groupby("Country")["Index"].count()
print(country_count)
# Out:
# Country
# India    100
# Name: Index, dtype: int64

# %%
#12. City-wise Analysis

#Find:
#a.Top 10 cities by customer count
#print(df.groupby("City")["Index"].count().sort_values(ascending=False).head(10))
city_count = df['City'].value_counts()

print("\nTOP 10 CITIES")
print(city_count.head(10))
# Out:
# City
# Mumbai       10
# Ahmedabad     9
# Bangalore     9
# Chennai       9
# Delhi         9
# Hyderabad     9
# Jaipur        9
# Kolkata       9
# Lucknow       9
# Pune          9
# Name: Index, dtype: int64
#
# TOP 10 CITIES
# City
# Mumbai       10
# Delhi         9
# Pune          9
# Chennai       9
# Bangalore     9
# Hyderabad     9
# Kolkata       9
# Ahmedabad     9
# Lucknow       9
# Surat         9
# Name: count, dtype: int64

# %%
#13. Company Analysis

#a.Find:
company_count=df.groupby("Company")["Index"].count().sort_values(ascending=False)

#b.Company with most customers.
print(company_count.head(1))
#c.Top 5 companies.
print(company_count.head(5))
# Out:
# Company
# ByteWorks    10
# Name: Index, dtype: int64
# Company
# ByteWorks    10
# CloudCore    10
# DataSoft     10
# Innovix      10
# NextGen      10
# Name: Index, dtype: int64

# %%
#14.Subsripition Date
# Customers joined each 
df['Year'] = df['Subscription Date'].dt.year

print("\nCUSTOMERS JOINED EACH YEAR")
print(df['Year'].value_counts().sort_index())

# Customers joined each month

df['Month'] = df['Subscription Date'].dt.month_name()

print("\nCUSTOMERS JOINED EACH MONTH")
print(df['Month'].value_counts().sort_index())
# Out:
# CUSTOMERS JOINED EACH YEAR
# Year
# 2024    100
# Name: count, dtype: int64
#
# CUSTOMERS JOINED EACH MONTH
# Month
# April         5
# August        4
# December      4
# February     19
# January      22
# July          4
# June          4
# March        22
# May           4
# November      4
# October       4
# September     4
# Name: count, dtype: int64

# %%
#15. Email Provider Analysis

#Create chart for:

#Gmail users
#Yahoo users
#Outlook 
import matplotlib.pyplot as plt

provider_counts = {
    'gmail': (df['Email Domain'] == 'gmail.com').sum(),
    'yahoo': (df['Email Domain'] == 'yahoo.com').sum(),
    'outlook': (df['Email Domain'] == 'outlook.com').sum()
}

# plt.figure(figsize=(6,4))#doubt
plt.bar(provider_counts.keys(), provider_counts.values())
plt.title('Email Provider Analysis')
plt.xlabel('Provider')
plt.ylabel('Users')
plt.show()

# %%
#Part D — Matplotlib Practice
#16. Bar Chart

#Plot:

#Top 10 cities by customers.
import pandas as pd
import matplotlib.pyplot as plt
df.groupby("City")["Index"].count().head(10).plot(kind = "bar",x="City",y="Index")
plt.show()

# %%
#17. Pie Chart

#Show:

#Country distribution.
plt.figure(figsize=(8,8))
country_count.plot(kind='pie', autopct='%1.1f%%',colors=["gold"])
plt.title('Country Distribution')
plt.ylabel('')
plt.show()

# %%
# 18.LINE CHART
subscription_trend = df.groupby('Subscription Date')['Index'].count()

plt.figure(figsize=(10,5))
plt.plot(subscription_trend,c='r',marker='o')

plt.title('Subscriptions Over Time')
plt.xlabel('Date')
plt.ylabel('Customers')
plt.show()

# %%
#extra Q
#city Wise Customer
#Bar chart
city_count.head(5).plot(kind='bar',color="g")
plt.title("City Distrubution")
plt.xlabel('Customers')
plt.ylabel('City')
plt.show()

# %%
#19. Histogram

#Plot:

#Customers joined per month.
plt.figure(figsize=(8,5))
plt.hist(df['Month'])
plt.title('Customers Joined Per Month')
plt.xlabel('Month')
plt.ylabel('Customers')
plt.show()

# %%
#20. Horizontal Bar Chart

#Plot:

#Top companies by customer 
plt.figure(figsize=(10,5))
company_count.head(10).plot(kind='barh')
plt.title('Top Companies by Customer Count')
plt.xlabel('Customers')
plt.ylabel('Company')
plt.show()

# %%
#21. Customer Growth Analysis
#Find customer growth trend over months.

monthly_growth = df.groupby(['Year', 'Month'])['Index'].count()

print("\nCUSTOMER GROWTH TREND")
print(monthly_growth)
# Out:
# CUSTOMER GROWTH TREND
# Year  Month
# 2024  1        22
#       2        19
#       3        22
#       4         5
#       5         4
#       6         4
#       7         4
#       8         4
#       9         4
#       10        4
#       11        4
#       12        4
# Name: Index, dtype: int64

# %%
#22. Business Insight Questions

#Answer:

#Which country has most customers?
print(country_count.idxmax())
#Which company has highest registrations?
print(company_count.idxmax())
#Which email provider is most popular?
print(df["Email Domain"].mode())
# Out:
# India
# ByteWorks
# 0    gmail.com
# Name: Email Domain, dtype: object

# %%
# 23.detect invalid
# Invalid emails
invalid_emails = df[~df['Email'].str.contains('@', na=False)]

print("\nINVALID EMAILS")
print(invalid_emails)

# Missing websites
missing_websites = df[df['Website'].isnull()]

print("\nMISSING WEBSITES")
print(missing_websites)

# Incorrect phone numbers
df['Phone 1'] = df['Phone 1'].astype(str)
incorrect_phone = df[ (df['Phone 1'].str.len() < 10) | (df['Phone 1'].str.len() > 10)]

print("\nINCORRECT PHONE NUMBERS")
print(incorrect_phone)
# Out:
# INVALID EMAILS
# Empty DataFrame
# Columns: [Index, Customer Id, First Name, Last Name, Company, City, Country, Phone 1, Phone 2, Email, Subscription Date, Website, Full Name, Email Domain, Website Domain, Year, Month]
# Index: []
#
# MISSING WEBSITES
# Empty DataFrame
# Columns: [Index, Customer Id, First Name, Last Name, Company, City, Country, Phone 1, Phone 2, Email, Subscription Date, Website, Full Name, Email Domain, Website Domain, Year, Month]
# Index: []
#
# INCORRECT PHONE NUMBERS
#     Index Customer Id First Name Last Name    Company    City Country  \
# 11     12    CUST1012      Kiara  Malhotra   DataSoft  Mumbai   India
# 12     13    CUST1013       Yash     Gupta  CloudCore   Delhi   India
#
#         Phone 1     Phone 2                     Email Subscription Date  \
# 11    876500022  9122200022  kiara.malhotra@gmail.com        2024-01-16
# 12  98765040023  9122200023      yash.gupta@gmail.com        2024-01-17
#
#               Website       Full Name Email Domain Website Domain  Year  Month
# 11    www.datasoft.in  Kiara Malhotra    gmail.com             in  2024      1
# 12  www.cloudcore.net      Yash Gupta    gmail.com            net  2024      1

# %%
#24. CUSTOMER SEGMENTATION

# Segment by Country
country_segment=df.groupby("Country")["Index"].count()
print(country_segment)
#Segment by Company
company_segment=df.groupby("Company")["Index"].count().sort_values()
print(company_segment)
#Segment by Email
email_segment = df.groupby('Email Domain')['Index'].count().sort_values()
print(email_segment)
# Out:
# Country
# India    100
# Name: Index, dtype: int64
# Company
# Alphaoft       1
# DataHuTech     1
# VisionSb       1
# AlphaTech      9
# DataHub        9
# VisionSoft     9
# ByteWorks     10
# CloudCore     10
# DataSoft      10
# Innovix       10
# NextGen       10
# SoftEdge      10
# TechNova      10
# Name: Index, dtype: int64
# Email Domain
# outlook.com    11
# yahoo.com      29
# gmail.com      60
# Name: Index, dtype: int64

# %%
# =========================
# MAIN DASHBOARD
# =========================

plt.figure(figsize=(18, 12))

# Dashboard title
plt.suptitle('Customer Analytics Dashboard',fontsize=22,fontweight='bold')

# -------------------------
# 1. Country Distribution
# -------------------------
plt.subplot(2, 4, 1)

country_count.plot(kind='pie',autopct='%1.1f%%',colors=['gold'],startangle=90)

plt.title('Country Distribution')
plt.ylabel('')

# -------------------------
# 2. City Distribution
# -------------------------
plt.subplot(2, 4, 2)

city_count.head(5).plot(kind='bar',color='green')

plt.title('Top Cities')
plt.xlabel('City')
plt.ylabel('Customers')
plt.xticks(rotation=45)

# -------------------------
# 3. Company Distribution
# -------------------------
plt.subplot(2, 4, 3)

company_count.head(5).plot(kind='bar',color='red')

plt.title('Top Companies')
plt.xlabel('Company')
plt.ylabel('Customers')
plt.xticks(rotation=45)

# -------------------------
# 4. Subscription Trend
# -------------------------
plt.subplot(2, 4, 4)

plt.plot(subscription_trend,color='hotpink',marker='o',linewidth=2)

plt.title('Subscription Trend')
plt.xlabel('Date')
plt.ylabel('Customers')
plt.xticks(rotation=45)

# -------------------------
# 5. Email Provider Analysis
# -------------------------
plt.subplot(2, 4, 5)

plt.bar(provider_counts.keys(),provider_counts.values(),color='blue')

plt.title('Email Providers')
plt.xlabel('Provider')
plt.ylabel('Users')

# -------------------------
# 6. Website Analysis
# -------------------------
plt.subplot(2, 4, 6)

website_company = df.groupby('Company')['Website'].count()

website_company.plot(kind='bar',color='purple')

plt.title('Company vs Website')
plt.xlabel('Company')
plt.ylabel('Website Count')
plt.xticks(rotation=45)

# -------------------------
# 7. Top Companies by Customers
# -------------------------
plt.subplot(2, 4, 7)

company_count.head(5).plot(kind='barh',color='cyan')

plt.title('Top Companies by Customers')
plt.xlabel('Customers')
plt.ylabel('Company')

# -------------------------
# 8. Customers Joined Per Month
# -------------------------
plt.subplot(2, 4, 8)

plt.hist(df['Month'],bins=12,color='orange',edgecolor='black')

plt.title('Customers Joined Per Month')
plt.xlabel('Month')
plt.ylabel('Customers')
plt.xticks(rotation=45)

# -------------------------
# Layout Adjustment
# -------------------------
plt.tight_layout(rect=[0, 0, 1, 0.95])

# Show dashboard
plt.show()

print("\nPROJECT COMPLETED SUCCESSFULLY")
# Out:
# PROJECT COMPLETED SUCCESSFULLY
